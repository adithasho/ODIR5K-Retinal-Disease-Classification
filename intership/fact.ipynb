# %%
n=int(input("enter a number:"))
if(n%3==0 and n%5==0):
    print("fizz buzz")
elif(n%5==0):
    print("buzz")
elif(n%3==0):
    print("fizz")
else:
    print("invalid")

# %%
n=int(input("enter the total hours of parking"))
if(n<2):
    print("no fee needed")
elif(n>=3 and n<=5):
    s=n-2
    s=s*20
    print("the total parking fees is rs:",s)
else:
    s=60
    s=s+(n-5)*50
    print("the total parking fees is rs:",s)

# %%
n=int(input("enter the limit till you want to print"))
for i in range(1,n+1):
 print(i)

# %%
n=int(input("enter the number for which you want the factorial:"))
i=1
factorial=1
while i<=n:
    factorial=factorial*i
    i+=1
print(factorial)

# %%
print("welcome to calculater")
a=int(input("enter the first number"))
b=int(input("enter the second number"))
def add(a,b):
    result=a+b
    return(result)
def sub(a,b):
    result=a-b
    return(result)
def mul(a,b):
    result=a*b
    return(result)
def div(a,b):
    if(a==0):
        print("please enter an non zero digit")
    else:
        result=a/b
        return(result)
print(add(a,b))
print(sub(a,b))
print(mul(a,b))
print(div(a,b))

# %%
n=str(input("enter the number for which you want the count"))
print("the count is:",len(n))

# %%
oddsum=0
evensum=0
for _ in range (10):
 n=int(input("enter the numbers"))
 if(n%2==0):
  oddsum=oddsum+n
 else:
  evensum=evensum+n
print("the oddsum=",oddsum)
print("the evensum=",evensum)

# %%
print("welcome to atm")
def withdraw():
      balance=100
      currentbalance=withdrawamt-balance
      return(currentbalance)
def deposit():
      balance=100
      currentbalance=depositamt+balance
      return(currentbalance)

print("1.withdraw")
print("2.deposit")
print("3.exit")

choice=int(input("enter your choice"))
if(choice==1):
 withdrawamt=int(input("enter the amount you want to withdraw:"))
 print("new balance=:",withdraw())
elif(choice==2):
    depositamt=int(input("enter the amount you and deposite"))
    print("the new balance is:",deposit())
else:
 print("welcome to the interface")
# Out:
# welcome to atm
# 1.withdraw
# 2.deposit
# 3.exit
# new balance=: -50
